# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd

# Generating the datasets again using the provided code block

# Define the range of data and other parameters
num_additional_rows = 50
reporting_dates = ["Jan 1st", "April 1st", "July 1st", "Oct 1st"]
quarters = [1, 2, 3, 4]
clinic_names = [
    "Downtown Clinic", 
    "Uptown Clinic", 
    "Suburban Clinic", 
    "Riverside Clinic", 
    "Central Medical Center", 
    "Eastside Health Hub", 
    "West End Wellness Center", 
    "North Point Clinic", 
    "South Shore Medical"
]

# Generate additional data for "Patient Metrics"
np.random.seed(0)  # For reproducibility
additional_patient_data = {
    "Clinic Name": np.random.choice(clinic_names, num_additional_rows),
    "Reporting Date": np.random.choice(reporting_dates, num_additional_rows),
    "Quarter": np.random.choice(quarters, num_additional_rows),
    "Latest Report": np.random.choice([True, False], num_additional_rows),
    "Total Patients": np.random.randint(30, 150, num_additional_rows),
    "Successful Surgeries": np.random.randint(20, 120, num_additional_rows),
    "Medical Consultations": np.random.randint(20, 140, num_additional_rows),
    "Emergency Visits": np.random.randint(5, 100, num_additional_rows),
    "Patient Satisfaction Score (out of 100)": np.random.randint(60, 100, num_additional_rows)
}
additional_patient_df = pd.DataFrame(additional_patient_data)

# Generate additional data for "Operational Metrics"
choices = ["Yes", "No", "Maybe"]
efficiency_levels = ["High", "Moderate", "Low"]
additional_operational_data = {
    "Clinic Name": np.random.choice(clinic_names, num_additional_rows),
    "Reporting Date": np.random.choice(reporting_dates, num_additional_rows),
    "Quarter": np.random.choice(quarters, num_additional_rows),
    "Latest Report": np.random.choice([True, False], num_additional_rows),
    "Equipment Maintenance": np.random.choice(choices, num_additional_rows),
    "Medication Stock Available": np.random.choice(choices, num_additional_rows),
    "Cleanliness Standards Met": np.random.choice(choices, num_additional_rows),
    "Sufficient Staffing": np.random.choice(choices, num_additional_rows),
    "Patient Feedback Collected": np.random.choice(choices, num_additional_rows),
    "Operational Efficiency Level": np.random.choice(efficiency_levels, num_additional_rows)
}
additional_operational_df = pd.DataFrame(additional_operational_data)

# Initialize data and data_pt2 as empty DataFrames
data = pd.DataFrame()
data_pt2 = pd.DataFrame()

# Append the generated data to the empty DataFrames
Patient_Metric = pd.concat([data, additional_patient_df], ignore_index=True)
Operational_Metrics = pd.concat([data_pt2, additional_operational_df], ignore_index=True)

# Add a unique ID column
Operational_Metrics['RecordID'] = range(1, len(Operational_Metrics) + 1)

# Proceed with the aggregation for Patient_Metric
aggregated_patient_data = Patient_Metric.groupby(['Clinic Name', 'Quarter']).agg({
    'Total Patients': 'sum',
    'Successful Surgeries': 'sum',
    'Medical Consultations': 'sum',
    'Emergency Visits': 'sum',
    'Patient Satisfaction Score (out of 100)': 'mean'
}).reset_index()

# As for Reporting Date and Latest Report, they don't make sense to aggregate, 
# so we can simply take the most recent one for each group (assuming the data is sorted by date which isn't provided)
aggregated_patient_data['Reporting Date'] = Patient_Metric.groupby(['Clinic Name', 'Quarter'])['Reporting Date'].last().values
aggregated_patient_data['Latest Report'] = Patient_Metric.groupby(['Clinic Name', 'Quarter'])['Latest Report'].last().values

# Set 'Latest Report' to False for all rows
aggregated_patient_data['Latest Report'] = False
Operational_Metrics['Latest Report'] = False
Patient_Metric['Latest Report'] = False

# Set 'Latest Report' to True only for rows where 'Quarter' is 4
aggregated_patient_data.loc[aggregated_patient_data['Quarter'] == 4, 'Latest Report'] = True
Operational_Metrics.loc[Operational_Metrics['Quarter'] == 4, 'Latest Report'] = True
Patient_Metric.loc[Patient_Metric['Quarter'] == 4, 'Latest Report'] = True

# %%
# Step 1: Create a list of all combinations of clinics and quarters
all_combinations = [(clinic, quarter) for clinic in clinic_names for quarter in quarters]

# Step 2: Check which combinations are missing from the Patient_Metric dataset
missing_combinations_pt = [comb for comb in all_combinations if not ((Patient_Metric['Clinic Name'] == comb[0]) & (Patient_Metric['Quarter'] == comb[1])).any()]

# Step 3: Fill in these missing combinations with dummy or default data for Patient_Metric
for clinic, quarter in missing_combinations_pt:
    dummy_data = {
        "Clinic Name": clinic,
        "Reporting Date": reporting_dates[quarter-1],  # Use the quarter to get the reporting date
        "Quarter": quarter,
        "Latest Report": quarter == 4,
        "Total Patients": 0,
        "Successful Surgeries": 0,
        "Medical Consultations": 0,
        "Emergency Visits": 0,
        "Patient Satisfaction Score (out of 100)": 0
    }
    Patient_Metric = pd.concat([Patient_Metric, pd.DataFrame([dummy_data])], ignore_index=True)

# Step 2: Check which combinations are missing from the Operational_Metrics dataset
missing_combinations_op = [comb for comb in all_combinations if not ((Operational_Metrics['Clinic Name'] == comb[0]) & (Operational_Metrics['Quarter'] == comb[1])).any()]

# Step 3: Fill in these missing combinations with dummy or default data for Operational_Metrics
for clinic, quarter in missing_combinations_op:
    dummy_data = {
        "Clinic Name": clinic,
        "Reporting Date": reporting_dates[quarter-1],  # Use the quarter to get the reporting date
        "Quarter": quarter,
        "Latest Report": quarter == 4,
        "Equipment Maintenance": "Maybe",
        "Medication Stock Available": "Maybe",
        "Cleanliness Standards Met": "Maybe",
        "Sufficient Staffing": "Maybe",
        "Patient Feedback Collected": "Maybe",
        "Operational Efficiency Level": "Moderate"
    }
    Operational_Metrics = pd.concat([Operational_Metrics, pd.DataFrame([dummy_data])], ignore_index=True)
    Operational_Metrics['RecordID'] = range(1, len(Operational_Metrics) + 1)  # Reset RecordID to ensure uniqueness

# %%
# Calculate KPIs for Patient_Metric
Patient_Metric['Patient Experience Score'] = Patient_Metric['Patient Satisfaction Score (out of 100)']
Patient_Metric['Medical Efficacy Ratio'] = Patient_Metric['Successful Surgeries'] / Patient_Metric['Total Patients']
Patient_Metric['Service Demand Ratio'] = Patient_Metric['Emergency Visits'] / Patient_Metric['Medical Consultations']

# %%
# Define scoring system
score_mapping = {'Yes': 1, 'Maybe': 0, 'No': -1}
efficiency_mapping = {'High': 3, 'Moderate': 2, 'Low': 1}

# Score each metric
for column in ['Equipment Maintenance', 'Medication Stock Available', 'Cleanliness Standards Met', 'Sufficient Staffing', 'Patient Feedback Collected']:
    Operational_Metrics[column + ' Score'] = Operational_Metrics[column].map(score_mapping)

Operational_Metrics['Operational Efficiency Score'] = Operational_Metrics['Operational Efficiency Level'].map(efficiency_mapping)

# %%
aggregated_patient_data.loc[aggregated_patient_data['Quarter'] == 4].count()
# Out:
# Clinic Name                                8
# Quarter                                    8
# Total Patients                             8
# Successful Surgeries                       8
# Medical Consultations                      8
# Emergency Visits                           8
# Patient Satisfaction Score (out of 100)    8
# Reporting Date                             8
# Latest Report                              8
# dtype: int64

# %%
aggregated_patient_data
# Out:
#                  Clinic Name  Quarter  Total Patients  Successful Surgeries  \
# 0     Central Medical Center        1              54                   105
# 1     Central Medical Center        2             134                    71
# 2     Central Medical Center        3              68                    51
# 3     Central Medical Center        4              46                    52
# 4            Downtown Clinic        2             139                    96
# 5            Downtown Clinic        3             199                   192
# 6            Downtown Clinic        4             309                   208
# 7        Eastside Health Hub        2             309                   189
# 8        Eastside Health Hub        3             225                   107
# 9        Eastside Health Hub        4             105                   107
# 10        North Point Clinic        1             148                    47
# 11        North Point Clinic        2             161                   112
# 12        North Point Clinic        3              90                    22
# 13        North Point Clinic        4             336                   160
# 14          Riverside Clinic        1             103                   121
# 15          Riverside Clinic        2             355                   268
# 16          Riverside Clinic        3             333                   150
# 17          Riverside Clinic        4             119                    66
# 18       South Shore Medical        1              51                    30
# 19       South Shore Medical        2             287                   177
# 20       South Shore Medical        3             149                   102
# 21           Suburban Clinic        1             129                   118
# 22           Suburban Clinic        3             148                    91
# 23           Suburban Clinic        4              31                    47
# 24             Uptown Clinic        2             109                    70
# 25             Uptown Clinic        3              55                    57
# 26             Uptown Clinic        4             145                   202
# 27  West End Wellness Center        1             110                    48
# 28  West End Wellness Center        3              59                   104
# 29  West End Wellness Center        4             141                    54
#
#     Medical Consultations  Emergency Visits  \
# 0                     105                80
# 1                     136                 5
# 2                      89                77
# 3                      54                88
# 4                     108                35
# 5                     266               176
# 6                     302               236
# 7                     200               165
# 8                     170               127
# 9                      20                97
# 10                    101                96
# 11                    213               130
# 12                     21                94
# 13                    295               237
# 14                    109               113
# 15                    126               119
# 16                    299               173
# 17                     91               157
# 18                    100                98
# 19                    214               129
# 20                    110               135
# 21                    150                77
# 22                     86                86
# 23                     64                18
# 24                    104                37
# 25                     28                26
# 26                    104                89
# 27                     81                78
# 28                     73                46
# 29                     95                30
#
#     Patient Satisfaction Score (out of 100) Reporting Date  Latest Report
# 0                                 82.000000       July 1st          False
# 1                                 88.000000        Oct 1st          False
# 2                                 73.000000        Jan 1st          False
# 3                                 95.000000        Oct 1st           True
# 4                                 74.000000        Jan 1st          False
# 5                                 74.000000        Jan 1st          False
# 6                                 74.666667        Oct 1st           True
# 7                                 87.333333        Oct 1st          False
# 8                                 74.500000        Oct 1st          False
# 9                                 64.000000       July 1st           True
# 10                                75.000000       July 1st          False
# 11                                79.500000        Jan 1st          False
# 12                                68.000000        Oct 1st          False
# 13                                70.000000       July 1st           True
# 14                                84.000000        Jan 1st          False
# 15                                84.333333        Oct 1st          False
# 16                                83.000000        Jan 1st          False
# 17                                78.000000        Jan 1st           True
# 18                                68.000000      April 1st          False
# 19                                74.000000        Oct 1st          False
# 20                                88.500000        Jan 1st          False
# 21                                88.000000      April 1st          False
# 22                                73.000000        Oct 1st          False
# 23                                99.000000        Jan 1st           True
# 24                                95.000000        Jan 1st          False
# 25                                65.000000      April 1st          False
# 26                                77.000000        Oct 1st           True
# 27                                60.000000      April 1st          False
# 28                                67.000000      April 1st          False
# 29                                68.000000      April 1st           True

# %%
Operational_Metrics
# Out:
#                  Clinic Name Reporting Date  Quarter  Latest Report  \
# 0           Riverside Clinic        Jan 1st        3          False
# 1   West End Wellness Center       July 1st        1          False
# 2              Uptown Clinic      April 1st        4           True
# 3         North Point Clinic       July 1st        4           True
# 4     Central Medical Center       July 1st        4           True
# 5            Suburban Clinic      April 1st        1          False
# 6            Downtown Clinic        Oct 1st        2          False
# 7        South Shore Medical        Oct 1st        4           True
# 8            Suburban Clinic        Jan 1st        4           True
# 9         North Point Clinic        Jan 1st        3          False
# 10       South Shore Medical       July 1st        2          False
# 11    Central Medical Center      April 1st        4           True
# 12    Central Medical Center      April 1st        4           True
# 13             Uptown Clinic        Jan 1st        2          False
# 14        North Point Clinic        Oct 1st        2          False
# 15  West End Wellness Center        Jan 1st        1          False
# 16    Central Medical Center       July 1st        1          False
# 17             Uptown Clinic        Jan 1st        4           True
# 18       Eastside Health Hub        Oct 1st        3          False
# 19        North Point Clinic      April 1st        1          False
# 20             Uptown Clinic       July 1st        1          False
# 21          Riverside Clinic        Oct 1st        4           True
# 22       Eastside Health Hub       July 1st        3          False
# 23        North Point Clinic      April 1st        2          False
# 24          Riverside Clinic        Jan 1st        3          False
# 25  West End Wellness Center        Jan 1st        4           True
# 26  West End Wellness Center      April 1st        3          False
# 27        North Point Clinic        Jan 1st        4           True
# 28             Uptown Clinic        Jan 1st        4           True
# 29  West End Wellness Center       July 1st        1          False
# 30           Downtown Clinic        Jan 1st        4           True
# 31          Riverside Clinic        Jan 1st        3          False
# 32       South Shore Medical      April 1st        3          False
# 33    Central Medical Center        Oct 1st        1          False
# 34             Uptown Clinic      April 1st        4           True
# 35    Central Medical Center      April 1st        3          False
# 36       Eastside Health Hub      April 1st        2          False
# 37           Downtown Clinic      April 1st        1          False
# 38          Riverside Clinic        Oct 1st        4           True
# 39             Uptown Clinic      April 1st        2          False
# 40    Central Medical Center       July 1st        3          False
# 41    Central Medical Center        Jan 1st        2          False
# 42    Central Medical Center       July 1st        2          False
# 43           Downtown Clinic        Jan 1st        1          False
# 44           Downtown Clinic        Oct 1st        2          False
# 45       South Shore Medical        Oct 1st        2          False
# 46    Central Medical Center      April 1st        4           True
# 47  West End Wellness Center        Oct 1st        2          False
# 48          Riverside Clinic        Jan 1st        4           True
# 49          Riverside Clinic        Oct 1st        3          False
# 50           Downtown Clinic       July 1st        3          False
# 51             Uptown Clinic       July 1st        3          False
# 52           Suburban Clinic      April 1st        2          False
# 53           Suburban Clinic       July 1st        3          False
# 54          Riverside Clinic        Jan 1st        1          False
# 55          Riverside Clinic      April 1st        2          False
# 56       Eastside Health Hub        Jan 1st        1          False
# 57       Eastside Health Hub        Oct 1st        4           True
# 58       South Shore Medical        Jan 1st        1          False
#
#    Equipment Maintenance Medication Stock Available Cleanliness Standards Met  \
# 0                  Maybe                         No                     Maybe
# 1                    Yes                         No                        No
# 2                     No                        Yes                       Yes
# 3                     No                      Maybe                        No
# 4                  Maybe                         No                     Maybe
# 5                  Maybe                         No                        No
# 6                    Yes                         No                     Maybe
# 7                  Maybe                         No                        No
# 8                     No                      Maybe                        No
# 9                  Maybe                        Yes                     Maybe
# 10                   Yes                      Maybe                       Yes
# 11                    No                         No                       Yes
# 12                 Maybe                         No                        No
# 13                   Yes                         No                        No
# 14                 Maybe                         No                        No
# 15                    No                      Maybe                       Yes
# 16                 Maybe                        Yes                     Maybe
# 17                    No                         No                     Maybe
# 18                   Yes                      Maybe                     Maybe
# 19                   Yes                         No                       Yes
# 20                    No                         No                     Maybe
# 21                   Yes                         No                       Yes
# 22                 Maybe                      Maybe                        No
# 23                   Yes                        Yes                     Maybe
# 24                    No                      Maybe                     Maybe
# 25                 Maybe                      Maybe                       Yes
# 26                   Yes                      Maybe                        No
# 27                 Maybe                      Maybe                     Maybe
# 28                   Yes                      Maybe                       Yes
# 29                   Yes                        Yes                       Yes
# 30                    No                         No                     Maybe
# 31                   Yes                         No                        No
# 32                    No                      Maybe                     Maybe
# 33                   Yes                      Maybe                       Yes
# 34                 Maybe                      Maybe                       Yes
# 35                   Yes                         No                       Yes
# 36                 Maybe                         No                        No
# 37                    No                         No                       Yes
# 38                   Yes                      Maybe                        No
# 39                 Maybe                      Maybe                       Yes
# 40                   Yes                         No                        No
# 41                 Maybe                      Maybe                     Maybe
# 42                   Yes                        Yes                        No
# 43                 Maybe                         No                     Maybe
# 44                 Maybe                         No                        No
# 45                   Yes                      Maybe                     Maybe
# 46                   Yes                        Yes                        No
# 47                 Maybe                         No                     Maybe
# 48                    No                        Yes                       Yes
# 49                    No                        Yes                     Maybe
# 50                 Maybe                      Maybe                     Maybe
# 51                 Maybe                      Maybe                     Maybe
# 52                 Maybe                      Maybe                     Maybe
# 53                 Maybe                      Maybe                     Maybe
# 54                 Maybe                      Maybe                     Maybe
# 55                 Maybe                      Maybe                     Maybe
# 56                 Maybe                      Maybe                     Maybe
# 57                 Maybe                      Maybe                     Maybe
# 58                 Maybe                      Maybe                     Maybe
#
#    Sufficient Staffing Patient Feedback Collected  \
# 0                   No                        Yes
# 1                  Yes                      Maybe
# 2                  Yes                      Maybe
# 3                Maybe                         No
# 4                Maybe                      Maybe
# 5                  Yes                      Maybe
# 6                Maybe                      Maybe
# 7                  Yes                      Maybe
# 8                  Yes                      Maybe
# 9                Maybe                        Yes
# 10               Maybe                      Maybe
# 11                  No                        Yes
# 12               Maybe                        Yes
# 13                 Yes                         No
# 14                 Yes                         No
# 15                  No                      Maybe
# 16                  No                         No
# 17                 Yes                        Yes
# 18                  No                      Maybe
# 19                 Yes                         No
# 20               Maybe                        Yes
# 21                 Yes                         No
# 22                  No                      Maybe
# 23               Maybe                         No
# 24                 Yes                      Maybe
# 25                 Yes                      Maybe
# 26                  No                         No
# 27                  No                      Maybe
# 28                 Yes                      Maybe
# 29               Maybe                      Maybe
# 30                  No                      Maybe
# 31               Maybe                         No
# 32                  No                      Maybe
# 33               Maybe                      Maybe
# 34                 Yes                      Maybe
# 35               Maybe                      Maybe
# 36                 Yes                        Yes
# 37               Maybe                         No
# 38                 Yes                         No
# 39                 Yes                        Yes
# 40               Maybe                         No
# 41                  No                        Yes
# 42                 Yes                         No
# 43               Maybe                         No
# 44                 Yes                      Maybe
# 45                 Yes                        Yes
# 46               Maybe                        Yes
# 47                 Yes                         No
# 48                  No                        Yes
# 49               Maybe                      Maybe
# 50               Maybe                      Maybe
# 51               Maybe                      Maybe
# 52               Maybe                      Maybe
# 53               Maybe                      Maybe
# 54               Maybe                      Maybe
# 55               Maybe                      Maybe
# 56               Maybe                      Maybe
# 57               Maybe                      Maybe
# 58               Maybe                      Maybe
#
#    Operational Efficiency Level  RecordID  Equipment Maintenance Score  \
# 0                      Moderate         1                            0
# 1                      Moderate         2                            1
# 2                           Low         3                           -1
# 3                          High         4                           -1
# 4                          High         5                            0
# 5                      Moderate         6                            0
# 6                      Moderate         7                            1
# 7                           Low         8                            0
# 8                          High         9                           -1
# 9                          High        10                            0
# 10                         High        11                            1
# 11                          Low        12                           -1
# 12                          Low        13                            0
# 13                     Moderate        14                            1
# 14                     Moderate        15                            0
# 15                     Moderate        16                           -1
# 16                     Moderate        17                            0
# 17                         High        18                           -1
# 18                         High        19                            1
# 19                         High        20                            1
# 20                         High        21                           -1
# 21                          Low        22                            1
# 22                          Low        23                            0
# 23                         High        24                            1
# 24                     Moderate        25                           -1
# 25                         High        26                            0
# 26                     Moderate        27                            1
# 27                          Low        28                            0
# 28                          Low        29                            1
# 29                     Moderate        30                            1
# 30                         High        31                           -1
# 31                         High        32                            1
# 32                     Moderate        33                           -1
# 33                         High        34                            1
# 34                         High        35                            0
# 35                          Low        36                            1
# 36                     Moderate        37                            0
# 37                         High        38                           -1
# 38                          Low        39                            1
# 39                         High        40                            0
# 40                         High        41                            1
# 41                     Moderate        42                            0
# 42                         High        43                            1
# 43                          Low        44                            0
# 44                         High        45                            0
# 45                     Moderate        46                            1
# 46                         High        47                            1
# 47                         High        48                            0
# 48                     Moderate        49                           -1
# 49                         High        50                           -1
# 50                     Moderate        51                            0
# 51                     Moderate        52                            0
# 52                     Moderate        53                            0
# 53                     Moderate        54                            0
# 54                     Moderate        55                            0
# 55                     Moderate        56                            0
# 56                     Moderate        57                            0
# 57                     Moderate        58                            0
# 58                     Moderate        59                            0
#
#     Medication Stock Available Score  Cleanliness Standards Met Score  \
# 0                                 -1                                0
# 1                                 -1                               -1
# 2                                  1                                1
# 3                                  0                               -1
# 4                                 -1                                0
# 5                                 -1                               -1
# 6                                 -1                                0
# 7                                 -1                               -1
# 8                                  0                               -1
# 9                                  1                                0
# 10                                 0                                1
# 11                                -1                                1
# 12                                -1                               -1
# 13                                -1                               -1
# 14                                -1                               -1
# 15                                 0                                1
# 16                                 1                                0
# 17                                -1                                0
# 18                                 0                                0
# 19                                -1                                1
# 20                                -1                                0
# 21                                -1                                1
# 22                                 0                               -1
# 23                                 1                                0
# 24                                 0                                0
# 25                                 0                                1
# 26                                 0                               -1
# 27                                 0                                0
# 28                                 0                                1
# 29                                 1                                1
# 30                                -1                                0
# 31                                -1                               -1
# 32                                 0                                0
# 33                                 0                                1
# 34                                 0                                1
# 35                                -1                                1
# 36                                -1                               -1
# 37                                -1                                1
# 38                                 0                               -1
# 39                                 0                                1
# 40                                -1                               -1
# 41                                 0                                0
# 42                                 1                               -1
# 43                                -1                                0
# 44                                -1                               -1
# 45                                 0                                0
# 46                                 1                               -1
# 47                                -1                                0
# 48                                 1                                1
# 49                                 1                                0
# 50                                 0                                0
# 51                                 0                                0
# 52                                 0                                0
# 53                                 0                                0
# 54                                 0                                0
# 55                                 0                                0
# 56                                 0                                0
# 57                                 0                                0
# 58                                 0                                0
#
#     Sufficient Staffing Score  Patient Feedback Collected Score  \
# 0                          -1                                 1
# 1                           1                                 0
# 2                           1                                 0
# 3                           0                                -1
# 4                           0                                 0
# 5                           1                                 0
# 6                           0                                 0
# 7                           1                                 0
# 8                           1                                 0
# 9                           0                                 1
# 10                          0                                 0
# 11                         -1                                 1
# 12                          0                                 1
# 13                          1                                -1
# 14                          1                                -1
# 15                         -1                                 0
# 16                         -1                                -1
# 17                          1                                 1
# 18                         -1                                 0
# 19                          1                                -1
# 20                          0                                 1
# 21                          1                                -1
# 22                         -1                                 0
# 23                          0                                -1
# 24                          1                                 0
# 25                          1                                 0
# 26                         -1                                -1
# 27                         -1                                 0
# 28                          1                                 0
# 29                          0                                 0
# 30                         -1                                 0
# 31                          0                                -1
# 32                         -1                                 0
# 33                          0                                 0
# 34                          1                                 0
# 35                          0                                 0
# 36                          1                                 1
# 37                          0                                -1
# 38                          1                                -1
# 39                          1                                 1
# 40                          0                                -1
# 41                         -1                                 1
# 42                          1                                -1
# 43                          0                                -1
# 44                          1                                 0
# 45                          1                                 1
# 46                          0                                 1
# 47                          1                                -1
# 48                         -1                                 1
# 49                          0                                 0
# 50                          0                                 0
# 51                          0                                 0
# 52                          0                                 0
# 53                          0                                 0
# 54                          0                                 0
# 55                          0                                 0
# 56                          0                                 0
# 57                          0                                 0
# 58                          0                                 0
#
#     Operational Efficiency Score
# 0                              2
# 1                              2
# 2                              1
# 3                              3
# 4                              3
# 5                              2
# 6                              2
# 7                              1
# 8                              3
# 9                              3
# 10                             3
# 11                             1
# 12                             1
# 13                             2
# 14                             2
# 15                             2
# 16                             2
# 17                             3
# 18                             3
# 19                             3
# 20                             3
# 21                             1
# 22                             1
# 23                             3
# 24                             2
# 25                             3
# 26                             2
# 27                             1
# 28                             1
# 29                             2
# 30                             3
# 31                             3
# 32                             2
# 33                             3
# 34                             3
# 35                             1
# 36                             2
# 37                             3
# 38                             1
# 39                             3
# 40                             3
# 41                             2
# 42                             3
# 43                             1
# 44                             3
# 45                             2
# 46                             3
# 47                             3
# 48                             2
# 49                             3
# 50                             2
# 51                             2
# 52                             2
# 53                             2
# 54                             2
# 55                             2
# 56                             2
# 57                             2
# 58                             2

# %%
Patient_Metric
# Out:
#                  Clinic Name Reporting Date  Quarter  Latest Report  \
# 0        Eastside Health Hub        Jan 1st        2          False
# 1            Downtown Clinic        Jan 1st        2          False
# 2           Riverside Clinic      April 1st        1          False
# 3           Riverside Clinic        Oct 1st        2          False
# 4         North Point Clinic        Jan 1st        2          False
# 5           Riverside Clinic      April 1st        2          False
# 6        Eastside Health Hub       July 1st        4           True
# 7            Suburban Clinic       July 1st        1          False
# 8     Central Medical Center        Oct 1st        4           True
# 9         North Point Clinic        Jan 1st        2          False
# 10  West End Wellness Center      April 1st        3          False
# 11       South Shore Medical      April 1st        1          False
# 12       South Shore Medical        Oct 1st        2          False
# 13             Uptown Clinic      April 1st        3          False
# 14  West End Wellness Center      April 1st        1          False
# 15        North Point Clinic        Oct 1st        3          False
# 16        North Point Clinic       July 1st        1          False
# 17       South Shore Medical        Oct 1st        2          False
# 18             Uptown Clinic        Oct 1st        4           True
# 19       Eastside Health Hub       July 1st        3          False
# 20       South Shore Medical       July 1st        3          False
# 21    Central Medical Center        Oct 1st        2          False
# 22          Riverside Clinic        Jan 1st        1          False
# 23           Downtown Clinic       July 1st        4           True
# 24          Riverside Clinic        Oct 1st        2          False
# 25       Eastside Health Hub      April 1st        2          False
# 26           Downtown Clinic        Jan 1st        4           True
# 27           Suburban Clinic      April 1st        1          False
# 28          Riverside Clinic       July 1st        3          False
# 29       South Shore Medical        Jan 1st        3          False
# 30             Uptown Clinic        Oct 1st        4           True
# 31          Riverside Clinic        Jan 1st        3          False
# 32          Riverside Clinic       July 1st        4           True
# 33          Riverside Clinic        Jan 1st        4           True
# 34        North Point Clinic        Oct 1st        4           True
# 35           Downtown Clinic        Oct 1st        3          False
# 36             Uptown Clinic        Jan 1st        2          False
# 37           Downtown Clinic        Oct 1st        3          False
# 38    Central Medical Center        Jan 1st        3          False
# 39        North Point Clinic        Jan 1st        4           True
# 40          Riverside Clinic        Jan 1st        3          False
# 41           Suburban Clinic        Jan 1st        4           True
# 42        North Point Clinic       July 1st        4           True
# 43           Suburban Clinic        Oct 1st        3          False
# 44           Downtown Clinic        Jan 1st        3          False
# 45           Downtown Clinic        Oct 1st        4           True
# 46    Central Medical Center       July 1st        1          False
# 47       Eastside Health Hub        Oct 1st        2          False
# 48       Eastside Health Hub        Oct 1st        3          False
# 49  West End Wellness Center      April 1st        4           True
# 50           Downtown Clinic        Jan 1st        1          False
# 51             Uptown Clinic        Jan 1st        1          False
# 52           Suburban Clinic      April 1st        2          False
# 53       Eastside Health Hub        Jan 1st        1          False
# 54  West End Wellness Center      April 1st        2          False
# 55       South Shore Medical        Oct 1st        4           True
#
#     Total Patients  Successful Surgeries  Medical Consultations  \
# 0               97                    23                     54
# 1              139                    96                    108
# 2               41                    55                     53
# 3              116                   106                     25
# 4              107                    81                    124
# 5              139                    89                     56
# 6              105                   107                     20
# 7               86                    63                     95
# 8               46                    52                     54
# 9               54                    31                     89
# 10              59                   104                     73
# 11              51                    30                    100
# 12             140                    74                     82
# 13              55                    57                     28
# 14             110                    48                     81
# 15              90                    22                     21
# 16             148                    47                    101
# 17             147                   103                    132
# 18              91                   109                     55
# 19             113                    43                    111
# 20              63                    73                     60
# 21             134                    71                    136
# 22              62                    66                     56
# 23             130                    40                     68
# 24             100                    73                     45
# 25             115                    49                     87
# 26              61                    87                    123
# 27              43                    55                     55
# 28             101                    59                    134
# 29              86                    29                     50
# 30              54                    93                     49
# 31             109                    61                    133
# 32              71                    43                     53
# 33              48                    23                     38
# 34              70                    66                     37
# 35              84                   110                    113
# 36             109                    70                    104
# 37              41                    23                     22
# 38              68                    51                     89
# 39             141                    29                    121
# 40             123                    30                     32
# 41              31                    47                     64
# 42             125                    65                    137
# 43             148                    91                     86
# 44              74                    59                    131
# 45             118                    81                    111
# 46              54                   105                    105
# 47              97                   117                     59
# 48             112                    64                     59
# 49             141                    54                     95
# 50               0                     0                      0
# 51               0                     0                      0
# 52               0                     0                      0
# 53               0                     0                      0
# 54               0                     0                      0
# 55               0                     0                      0
#
#     Emergency Visits  Patient Satisfaction Score (out of 100)  \
# 0                 27                                       92
# 1                 35                                       74
# 2                 22                                       82
# 3                 75                                       88
# 4                 76                                       80
# 5                 23                                       78
# 6                 97                                       64
# 7                 48                                       82
# 8                 88                                       95
# 9                 54                                       79
# 10                46                                       67
# 11                98                                       68
# 12                51                                       73
# 13                26                                       65
# 14                78                                       60
# 15                94                                       68
# 16                96                                       75
# 17                78                                       75
# 18                33                                       71
# 19                86                                       64
# 20                63                                       99
# 21                 5                                       88
# 22                91                                       86
# 23                68                                       70
# 24                21                                       87
# 25                41                                       95
# 26                99                                       78
# 27                29                                       94
# 28                68                                       90
# 29                72                                       78
# 30                56                                       83
# 31                13                                       61
# 32                61                                       66
# 33                96                                       90
# 34                98                                       76
# 35                92                                       86
# 36                37                                       95
# 37                24                                       69
# 38                77                                       73
# 39                76                                       66
# 40                92                                       98
# 41                18                                       99
# 42                63                                       68
# 43                86                                       73
# 44                60                                       67
# 45                69                                       76
# 46                80                                       82
# 47                97                                       75
# 48                41                                       85
# 49                30                                       68
# 50                 0                                        0
# 51                 0                                        0
# 52                 0                                        0
# 53                 0                                        0
# 54                 0                                        0
# 55                 0                                        0
#
#     Patient Experience Score  Medical Efficacy Ratio  Service Demand Ratio
# 0                         92                0.237113              0.500000
# 1                         74                0.690647              0.324074
# 2                         82                1.341463              0.415094
# 3                         88                0.913793              3.000000
# 4                         80                0.757009              0.612903
# 5                         78                0.640288              0.410714
# 6                         64                1.019048              4.850000
# 7                         82                0.732558              0.505263
# 8                         95                1.130435              1.629630
# 9                         79                0.574074              0.606742
# 10                        67                1.762712              0.630137
# 11                        68                0.588235              0.980000
# 12                        73                0.528571              0.621951
# 13                        65                1.036364              0.928571
# 14                        60                0.436364              0.962963
# 15                        68                0.244444              4.476190
# 16                        75                0.317568              0.950495
# 17                        75                0.700680              0.590909
# 18                        71                1.197802              0.600000
# 19                        64                0.380531              0.774775
# 20                        99                1.158730              1.050000
# 21                        88                0.529851              0.036765
# 22                        86                1.064516              1.625000
# 23                        70                0.307692              1.000000
# 24                        87                0.730000              0.466667
# 25                        95                0.426087              0.471264
# 26                        78                1.426230              0.804878
# 27                        94                1.279070              0.527273
# 28                        90                0.584158              0.507463
# 29                        78                0.337209              1.440000
# 30                        83                1.722222              1.142857
# 31                        61                0.559633              0.097744
# 32                        66                0.605634              1.150943
# 33                        90                0.479167              2.526316
# 34                        76                0.942857              2.648649
# 35                        86                1.309524              0.814159
# 36                        95                0.642202              0.355769
# 37                        69                0.560976              1.090909
# 38                        73                0.750000              0.865169
# 39                        66                0.205674              0.628099
# 40                        98                0.243902              2.875000
# 41                        99                1.516129              0.281250
# 42                        68                0.520000              0.459854
# 43                        73                0.614865              1.000000
# 44                        67                0.797297              0.458015
# 45                        76                0.686441              0.621622
# 46                        82                1.944444              0.761905
# 47                        75                1.206186              1.644068
# 48                        85                0.571429              0.694915
# 49                        68                0.382979              0.315789
# 50                         0                     NaN                   NaN
# 51                         0                     NaN                   NaN
# 52                         0                     NaN                   NaN
# 53                         0                     NaN                   NaN
# 54                         0                     NaN                   NaN
# 55                         0                     NaN                   NaN

# %%
# Exporting the DataFrames to Excel

excel_filepath = "Clinic Metrics.xlsx"
with pd.ExcelWriter(excel_filepath) as writer:
    aggregated_patient_data.to_excel(writer, sheet_name='Aggregated_Patient_Data', index=False)
    Operational_Metrics.to_excel(writer, sheet_name='Operational_Metrics', index=False)
    Patient_Metric.to_excel(writer, sheet_name='Patient_Metric', index=False)
